# %%
# Import necessary packages
import json
import os
import asyncio
from datetime import datetime
from pathlib import Path

from dotenv import load_dotenv
from IPython.display import display, HTML, Markdown
from typing import Annotated, Optional

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.connectors.ai.completion_usage import CompletionUsage
from semantic_kernel.contents import ChatHistorySummarizationReducer
from semantic_kernel.functions import kernel_function

# %%
class ScratchpadPlugin:
    """Plugin for managing agent scratchpad - a persistent memory for user preferences and completed tasks"""
    
    def __init__(self, filepath: str = "agent_scratchpad.md"):
        self.filepath = Path(filepath)
        # Initialize scratchpad if it doesn't exist
        if not self.filepath.exists():
            self.filepath.write_text("# Agent Scratchpad\n\n## User Preferences\n\n## Completed Tasks\n\n")
    
    @kernel_function(
        description="Read the current agent scratchpad to get user's travel preferences and completed tasks"
    )
    def read_scratchpad(self) -> Annotated[str, "The contents of the agent scratchpad"]:
        """Read the current scratchpad contents"""
        return self.filepath.read_text()
    
    @kernel_function(
        description="Update the agent scratchpad with new user's travel preference or completed tasks"
    )
    def update_scratchpad(
        self,
        category: Annotated[str, "Category to update: 'preferences' or 'tasks'"],
        content: Annotated[str, "The new content to add"]
    ) -> Annotated[str, "Confirmation of the update"]:
        """Update the scratchpad with new information"""
        current_content = self.filepath.read_text()
        timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        
        if category.lower() == "preferences":
            # Find the preferences section and append
            lines = current_content.split("\n")
            for i, line in enumerate(lines):
                if "## User Preferences" in line:
                    lines.insert(i + 1, f"\n- [{timestamp}] {content}")
                    break
            current_content = "\n".join(lines)
        elif category.lower() == "tasks":
            # Find the tasks section and append
            lines = current_content.split("\n")
            for i, line in enumerate(lines):
                if "## Completed Tasks" in line:
                    lines.insert(i + 1, f"\n- [{timestamp}] {content}")
                    break
            current_content = "\n".join(lines)
        
        self.filepath.write_text(current_content)
        return f"✅ Scratchpad updated with {category}: {content}"

# Create the scratchpad plugin
scratchpad_plugin = ScratchpadPlugin("vacation_agent_scratchpad.md")
print("📝 Scratchpad plugin created")
# Out:
# 📝 Scratchpad plugin created

# %%
# Configure reduction parameters
REDUCER_TARGET_COUNT = 5  # Target number of messages to keep after reduction
REDUCER_THRESHOLD = 15    # Trigger reduction when message count exceeds this

# Create the history summarization reducer
history_reducer = ChatHistorySummarizationReducer(
    service=AzureChatCompletion(),
    target_count=REDUCER_TARGET_COUNT,
    threshold_count=REDUCER_THRESHOLD,
)

print(f"🔄 Chat History Reducer configured:")
print(f"   - Reduction triggered at: {REDUCER_THRESHOLD} messages")
print(f"   - Reduces history to: {REDUCER_TARGET_COUNT} messages")
# Out:
# 🔄 Chat History Reducer configured:
#    - Reduction triggered at: 15 messages
#    - Reduces history to: 5 messages

# %%
agent = ChatCompletionAgent(
    service=AzureChatCompletion(),
    name="VacationPlannerAgent",
    instructions="""
    You are a helpful vacation planning assistant. Your job is to help users plan their perfect vacation.
    
    CRITICAL SCRATCHPAD RULES - YOU MUST FOLLOW THESE:
    1. FIRST ACTION: When starting ANY conversation, immediately call read_scratchpad() to check existing preferences
    2. AFTER LEARNING PREFERENCES: When user mentions ANY preference (destinations, activities, budget, dates), 
       immediately call update_scratchpad() with category 'preferences'
    3. AFTER COMPLETING TASKS: When you finish creating an itinerary or completing any task,
       immediately call update_scratchpad() with category 'tasks'
    4. BEFORE NEW ITINERARY: Always call read_scratchpad() before creating any itinerary
    
    EXAMPLES OF WHEN TO UPDATE SCRATCHPAD:
    - User says "I love beaches" → update_scratchpad('preferences', 'Loves beach destinations')
    - User says "budget is $3000" → update_scratchpad('preferences', 'Budget: $3000 per person for a week')
    - You create an itinerary → update_scratchpad('tasks', 'Created Bali itinerary for beach vacation')
    
    PLANNING PROCESS:
    1. Read scratchpad first
    2. Ask about preferences if not found
    3. Update scratchpad with new information
    4. Create detailed itineraries
    5. Update scratchpad with completed tasks
    
    BE EXPLICIT: Always announce when you're checking or updating the scratchpad.
    """,
    plugins=[scratchpad_plugin],
)

print("🤖 Vacation Planning Agent created with enhanced scratchpad instructions")
# Out:
# 🤖 Vacation Planning Agent created with enhanced scratchpad instructions

# %%
# Token tracking class
class TokenTracker:
    def __init__(self):
        self.history = []
        self.total_usage = CompletionUsage()
        self.reduction_events = []  # Track when reductions occur

    def add_usage(self, usage: CompletionUsage, message_num: int, thread_length: int = None):
        if usage:
            self.total_usage += usage
            entry = {
                "message_num": message_num,
                "prompt_tokens": usage.prompt_tokens,
                "completion_tokens": usage.completion_tokens,
                "total_tokens": usage.prompt_tokens + usage.completion_tokens,
                "cumulative_tokens": self.total_usage.prompt_tokens + self.total_usage.completion_tokens,
                "thread_length": thread_length
            }
            self.history.append(entry)

    def mark_reduction(self, message_num: int):
        self.reduction_events.append(message_num)

    def display_chart(self):
        """Display a chart showing token usage per message and the impact of reduction"""
        if not self.history:
            return

        html = "<div style='font-family: monospace; background: #2d2d2d; color: #f0f0f0; padding: 15px; border-radius: 8px; border: 1px solid #444;'>"
        html += "<h4 style='color: #4fc3f7; margin-top: 0;'>📊 Token Usage Analysis</h4>"
        html += "<pre style='color: #f0f0f0; margin: 0;'>"

        # Show prompt tokens per message to see reduction impact
        html += "<span style='color: #81c784;'>Prompt Tokens per Message (shows conversation context size):</span>\n"
        max_prompt = max(h["prompt_tokens"] for h in self.history)
        scale = 50 / max_prompt if max_prompt > 0 else 1

        for i, h in enumerate(self.history):
            bar_length = int(h["prompt_tokens"] * scale)
            bar = "█" * bar_length
            reduction_marker = " <span style='color: #ff6b6b;'>← REDUCTION!</span>" if h[
                "message_num"] in self.reduction_events else ""
            html += f"<span style='color: #aaa;'>Msg {h['message_num']:2d}:</span> <span style='color: #4fc3f7;'>{bar}</span> <span style='color: #ffd93d;'>{h['prompt_tokens']:,} tokens</span>{reduction_marker}\n"

        html += "\n</pre></div>"
        display(HTML(html))

        # Calculate reduction impact
        if self.reduction_events:
            # Find the message before and after first reduction
            first_reduction_msg = self.reduction_events[0]
            before_reduction = None
            after_reduction = None

            for h in self.history:
                if h["message_num"] == first_reduction_msg - 1:
                    before_reduction = h["prompt_tokens"]
                elif h["message_num"] == first_reduction_msg:
                    after_reduction = h["prompt_tokens"]

            if before_reduction and after_reduction:
                reduction_amount = before_reduction - after_reduction
                reduction_percent = (reduction_amount / before_reduction * 100)
                print(f"\n🔄 Actual Reduction Impact:")
                print(f"Prompt tokens before reduction: {before_reduction:,}")
                print(f"Prompt tokens after reduction: {after_reduction:,}")
                print(
                    f"Tokens saved: {reduction_amount:,} ({reduction_percent:.1f}%)")

# Display function for clean output


def display_message(role: str, content: str, color: str = "#2E8B57"):
    """Display a message with nice formatting that works in both light and dark themes"""
    # Use a semi-transparent background that adapts to the theme
    html = f"""
    <div style='
        margin: 10px 0; 
        padding: 12px 15px; 
        border-left: 4px solid {color}; 
        background: rgba(128, 128, 128, 0.1); 
        border-radius: 4px;
        color: inherit;
    '>
        <strong style='color: {color}; font-size: 14px;'>{role}:</strong><br>
        <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>{content}</div>
    </div>
    """
    display(HTML(html))


# Initialize token tracker
token_tracker = TokenTracker()
print("📊 Token tracking initialized")
# Out:
# 📊 Token tracking initialized

# %%
# Define the conversation flow
user_inputs = [
    "I'm thinking about planning a vacation. Can you help me?",
    "I love beach destinations with great food and culture. I enjoy water sports, exploring local markets, and trying authentic cuisine. My budget is around $3000 per person for a week.",
    "That sounds perfect! Please create a detailed itinerary for Bali.",
    "Actually, I've changed my mind. I'd prefer to go to the Greek islands instead. Can you create a new itinerary?",
    "What's the weather like there?",
    "What should I pack?",
    "Are there any cultural customs I should know about?",
    "What's the best way to get around?"
]


async def run_vacation_planning():
    """Run the vacation planning conversation with token tracking and history reduction"""

    # Create thread with history reducer
    thread = ChatHistoryAgentThread(chat_history=history_reducer)
    message_count = 0
    scratchpad_operations = 0  # Track scratchpad usage

    print("🚀 Starting Vacation Planning Session\n")

    # Process conversation
    for i, user_input in enumerate(user_inputs):
        message_count += 1
        display_message("User", user_input, "#4fc3f7")  # Blue for user

        # Get agent response
        full_response = ""
        usage = None
        function_calls = []  # Track function calls

        async for response in agent.invoke(
            messages=user_input,
            thread=thread,
        ):
            if response.content:
                full_response += str(response.content)
            if response.metadata.get("usage"):
                usage = response.metadata["usage"]
            thread = response.thread

        display_message(f"{agent.name}", full_response,
                        "#81c784")  # Green for agent

        # Track tokens with thread length
        if usage:
            token_tracker.add_usage(usage, message_count, len(thread))

        # Check thread status and look for scratchpad operations
        print(f"📝 Thread has {len(thread)} messages")

        # Count scratchpad operations in this turn
        turn_scratchpad_ops = 0
        async for msg in thread.get_messages():
            if hasattr(msg, 'content') and msg.content:
                content_str = str(msg.content)
                if 'read_scratchpad' in content_str or 'update_scratchpad' in content_str:
                    turn_scratchpad_ops += 1

        if turn_scratchpad_ops > scratchpad_operations:
            print(
                f"   📝 Scratchpad operations detected: {turn_scratchpad_ops - scratchpad_operations} new operations")
            scratchpad_operations = turn_scratchpad_ops

        # Show message types for first message
        if i == 0:
            message_types = []
            async for msg in thread.get_messages():
                msg_type = msg.role.value if hasattr(
                    msg.role, 'value') else str(msg.role)
                message_types.append(msg_type)
            print(f"   Message types: {message_types[:10]}..." if len(
                message_types) > 10 else f"   Message types: {message_types}")

        # Check if reduction should happen
        if len(thread) > REDUCER_THRESHOLD:
            print(
                f"   ⚠️ Thread length ({len(thread)}) exceeds threshold ({REDUCER_THRESHOLD})")

            # Attempt reduction
            is_reduced = await thread.reduce()
            if is_reduced:
                print(
                    f"\n🔄 HISTORY REDUCED! Thread now has {len(thread)} messages\n")
                token_tracker.mark_reduction(message_count + 1)

                # Show summary if available
                async for msg in thread.get_messages():
                    if msg.metadata and msg.metadata.get("__summary__"):
                        display_message("System Summary", str(
                            msg.content), "#ff6b6b")
                        break

    # Display final token usage chart
    print("\n--- Token Usage Analysis ---")
    token_tracker.display_chart()

    # Show final scratchpad contents
    print("\n--- Final Scratchpad Contents ---")
    scratchpad_contents = scratchpad_plugin.read_scratchpad()
    display(Markdown(scratchpad_contents))

    print(f"\n📊 Total scratchpad operations: {scratchpad_operations}")

    return thread

# Run the conversation
thread = await run_vacation_planning()
# Out:
# 🚀 Starting Vacation Planning Session
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I'm thinking about planning a vacation. Can you help me?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I just checked the scratchpad, and there are no existing preferences saved. Could you share some details about your vacation plans? For example:
#
# - Any specific destinations you're considering?
# - Activities or experiences you want to include?
# - Your budget or preferred travel dates?
#
# The more details, the better!</div>
#     </div>
# 📝 Thread has 4 messages
#    Message types: ['user', 'assistant', 'tool', 'assistant']
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I love beach destinations with great food and culture. I enjoy water sports, exploring local markets, and trying authentic cuisine. My budget is around $3000 per person for a week.</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Thank you! I've updated your preferences in my scratchpad:
#
# - You love beach destinations with great food and culture.
# - You enjoy water sports, exploring local markets, and trying authentic cuisine.
# - Your budget is $3000 per person for a week.
#
# Would you like me to suggest a destination or start planning an itinerary for a specific place?</div>
#     </div>
# 📝 Thread has 9 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>That sounds perfect! Please create a detailed itinerary for Bali.</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>I’ve checked the scratchpad to ensure your preferences are updated, and now I’ll create a detailed Bali itinerary for a week based on your love for beaches, culture, food, and activities like water sports and exploring local markets. Please hold on!
# **7-Day Itinerary for Bali**
#
# ---
#
# **Day 1: Arrival and Relaxation**
# - **Morning:** Arrive at Ngurah Rai International Airport. Check into a beachfront resort in Seminyak or Nusa Dua.
# - **Afternoon:** Relax on the beach and enjoy the serene views.
# - **Evening:** Dinner at a beachfront restaurant, such as Jimbaran Bay for fresh seafood.
#
# ---
#
# **Day 2: Uluwatu and Water Sports**
# - **Morning:** Head to Tanjung Benoa for water sports (jet skiing, parasailing, banana boat rides).
# - **Afternoon:** Visit Padang Padang Beach for sunbathing and swimming.
# - **Evening:** Watch the Kecak Fire Dance performance at Uluwatu Temple, followed by dinner with a view of the ocean.
#
# ---
#
# **Day 3: Cultural and Culinary Exploration in Ubud**
# - **Morning:** Visit Ubud Monkey Forest and Ubud Palace.
# - **Afternoon:** Take a Balinese cooking class to learn how to create authentic dishes.
# - **Evening:** Explore Ubud Market for local crafts and souvenirs.
#
# ---
#
# **Day 4: Island Hopping and Snorkeling**
# - **Morning:** Take a day trip to Nusa Penida or Nusa Lembongan. Snorkel in Crystal Bay or Manta Point.
# - **Afternoon:** Relax on the beaches and explore these pristine islands.
# - **Evening:** Return to Bali and enjoy a laid-back dinner in Seminyak.
#
# ---
#
# **Day 5: Temples and Rice Terraces**
# - **Morning:** Visit Tana Lot Temple, a sea temple on the cliffs.
# - **Afternoon:** Explore Tegallalang Rice Terraces and learn about traditional irrigation systems.
# - **Evening:** Dinner in Ubud with a view of the lush scenery.
#
# ---
#
# **Day 6: Beach Day and Spa**
# - **Morning:** Spend the day relaxing at Kuta or Sanur Beach.
# - **Afternoon:** Pamper yourself with a traditional Balinese spa treatment or massage.
# - **Evening:** Enjoy a high-end dinner in Seminyak at a place like Ku De Ta.
#
# ---
#
# **Day 7: Farewell**
# - **Morning:** Enjoy your final beach moments or shop for last-minute souvenirs.
# - **Afternoon:** Check out of the hotel and head to the airport for your flight home.
#
# ---
#
# Does this itinerary work for you, or would you like adjustments? Let me know!</div>
#     </div>
# 📝 Thread has 13 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Actually, I've changed my mind. I'd prefer to go to the Greek islands instead. Can you create a new itinerary?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Got it! You’ve shifted your preference to the Greek islands. I'll create a new detailed itinerary tailored to your interests in beaches, culture, authentic cuisine, water sports, and local markets. This will be specific to the Greek islands. Please hold on!
# **7-Day Itinerary for the Greek Islands (Santorini and Mykonos)**
#
# ---
#
# **Day 1: Arrival in Santorini**
# - **Morning:** Arrive at Santorini International Airport. Check into a luxury cliffside hotel in Oia or Fira for stunning caldera views.
# - **Afternoon:** Relax and enjoy the infinity pool or visit a nearby black sand beach.
# - **Evening:** Dinner at a restaurant with spectacular sunsets, like Kastro in Oia.
#
# ---
#
# **Day 2: Explore the Beauty of Santorini**
# - **Morning:** Take a boat tour to the volcanic islands of Nea Kameni and Palea Kameni. Swim in the hot springs and explore the volcanic craters.
# - **Afternoon:** Enjoy water sports or relax at Red Beach, known for its unique red-hued sand.
# - **Evening:** Walk through the charming streets of Fira and sample local dishes like moussaka and fava.
#
# ---
#
# **Day 3: Local Markets and Wine Tasting**
# - **Morning:** Visit a local market in Santorini to explore handmade jewelry, leather goods, and traditional Greek products.
# - **Afternoon:** Head to a local vineyard for a wine tasting tour, sampling the famed Assyrtiko wine.
# - **Evening:** Enjoy a Greek cooking class to learn how to make classics like tzatziki and baklava.
#
# ---
#
# **Day 4: Transfer to Mykonos**
# - **Morning:** Take a ferry to Mykonos. Check into a chic beachfront hotel in Ornos or Platis Gialos.
# - **Afternoon:** Explore the stunning Mykonos windmills and Little Venice.
# - **Evening:** Dine at a seaside taverna and enjoy a lively yet authentic Greek atmosphere.
#
# ---
#
# **Day 5: Beaches and Water Sports**
# - **Morning:** Head to Paradise Beach for water sports like jet skiing, windsurfing, or paddle boarding.
# - **Afternoon:** Visit Elia Beach for relaxation or Psarou Beach for vibrant beach clubs.
# - **Evening:** Sunset drinks at Scorpios beach club, followed by delicious Mediterranean cuisine.
#
# ---
#
# **Day 6: Cultural Immersion and Delos Island**
# - **Morning:** Take a half-day boat trip to the UNESCO World Heritage site of Delos. Explore the ancient ruins of temples, markets, and statues.
# - **Afternoon:** Return to Mykonos and explore the hidden alleys and markets of Chora for souvenirs.
# - **Evening:** Enjoy your farewell dinner at a fine-dining restaurant like Nobu Matsuhisa.
#
# ---
#
# **Day 7: Farewell**
# - **Morning:** Enjoy a leisurely breakfast with ocean views.
# - **Afternoon:** Check out of the hotel and head to the airport or ferry for your journey home.
#
# ---
#
# Would this Greek island itinerary align with your interests, or would you like any adjustments?</div>
#     </div>
# 📝 Thread has 19 messages
#    ⚠️ Thread length (19) exceeds threshold (15)
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>What's the weather like there?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>The Greek islands, particularly Santorini and Mykonos, generally enjoy a Mediterranean climate. Here's an overview of the weather you can expect:
#
# **Peak Summer (June to August)**
# - **Temperature:** 77°F to 95°F (25°C to 35°C).
# - **Details:** Warm, sunny, and dry, with little to no rain. Perfect beach weather and ideal for water sports.
# - **Pros:** Bustling atmosphere, longer daylight hours, and vibrant nightlife.
# - **Cons:** More crowded and higher prices during peak season.
#
# **Shoulder Seasons (April to May & September to October)**
# - **Temperature:** 64°F to 81°F (18°C to 27°C).
# - **Details:** Mild and pleasant with fewer tourists. Sea temperatures are comfortable for swimming, especially in September.
# - **Pros:** Quieter beaches, more affordable accommodations, and a relaxed vibe.
# - **Cons:** Some seasonal activities or services (like beach clubs or ferries) may be limited in early spring and late fall.
#
# **Winter (November to March)**
# - **Temperature:** 50°F to 60°F (10°C to 15°C).
# - **Details:** Cooler and occasional rain. Many tourist attractions and restaurants may close.
# - **Pros:** Great for cultural visits, photography, and a tranquil experience.
# - **Cons:** Not ideal for swimming or water sports, and ferry schedules are less frequent.
#
# If your timeline is flexible, I recommend traveling in late May, June, or September for the best mix of good weather, fewer crowds, and reasonable costs. When are you planning to go?</div>
#     </div>
# 📝 Thread has 21 messages
#    ⚠️ Thread length (21) exceeds threshold (15)
#
# 🔄 HISTORY REDUCED! Thread now has 9 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #ff6b6b;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #ff6b6b; font-size: 14px;'>System Summary:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>The user is planning a vacation and shared preferences for beach destinations with great food and culture, enjoying water sports, exploring local markets, and trying authentic cuisine, with a budget of $3000 per person for a week. They decided on Bali and requested a detailed 7-day itinerary. The assistant provided an itinerary featuring activities like water sports in Tanjung Benoa, cultural visits to Uluwatu Temple and Ubud, snorkeling trips to Nusa Penida, exploring Tegallalang Rice Terraces, and relaxing on beaches with spa treatments and high-end dining. The user can request adjustments or further details.</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>What should I pack?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Here’s a packing checklist tailored to the Greek islands, based on your interests and the weather:
#
# ---
#
# ### **Clothing**
# - **Lightweight clothing:** Pack breezy, breathable fabrics like cotton and linen to stay cool.
# - **Swimsuits:** Essential for beaches, poolside, and water sports.
# - **Cover-up or sarong:** For modesty when walking around or dining.
# - **Comfortable walking shoes:** Opt for sandals or sneakers for exploring ancient sites and island streets.
# - **Evening wear:** Bring a few dressy options for upscale restaurants and sunset dining.
# - **Light jacket or shawl:** Useful for cooler evenings, especially if visiting in spring or fall.
# - **Hat and sunglasses:** For sun protection during outdoor activities.
#
# ---
#
# ### **Beach & Water Sports Gear**
# - **Towel:** Bring a lightweight, quick-dry travel towel.
# - **Reef-safe sunscreen:** Essential for protecting both your skin and the marine environment during water activities.
# - **Waterproof bag:** To protect valuables during boat trips or water sports.
# - **Snorkeling gear:** Optional, but good to have for exploring vibrant underwater life.
#
# ---
#
# ### **Travel Essentials**
# - **Travel adapter:** Greece uses Type C or F plugs (220-240V).
# - **Reusable water bottle:** Stay hydrated during your adventures.
# - **Daypack or tote bag:** Handy for day trips, local markets, and boat rides.
# - **Travel documents:** Passport, flight/ferry tickets, hotel confirmations, travel insurance info, etc.
# - **Universal toiletries:** Toothbrush, toothpaste, deodorant, shampoo, etc.
#
# ---
#
# ### **Activities-Specific Items**
# - **Notebook/Journal:** Ideal for jotting down recipes from cooking classes or memorable spots.
# - **Camera/Smartphone:** For capturing iconic sunsets, villages, and beaches.
# - **Mesh bag:** For shopping at local markets and carrying souvenirs.
#
# ---
#
# ### **Health & Safety**
# - **Basic first aid kit:** Travel-size medications, band-aids, etc.
# - **Motion sickness tablets/bracelets:** If taking ferries or boat tours.
# - **Insect repellent:** Particularly useful for evenings or in spring/fall.
#
# ---
#
# This packing list ensures you’re prepared for beaches, sightseeing, local culture, and even high-end dining, aligning with your Greek islands itinerary. Let me know if you'd like to discuss anything in more detail!</div>
#     </div>
# 📝 Thread has 11 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Are there any cultural customs I should know about?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Absolutely! Understanding a few Greek customs will help you fit in and show respect for the local culture during your vacation. Here are some important tips:
#
# ---
#
# ### **General Customs**
# 1. **Greetings Matter:**
#    - Greeks typically greet with a handshake, especially for first meetings. Close friends may give a light kiss on both cheeks.
#    - Use polite phrases like "Kalimera" (Good morning), "Kalispera" (Good evening), and "Efharisto" (Thank you).
#
# 2. **Hospitality (Filoxenia) is Sacred:**
#    - Greeks are famously hospitable and value making visitors feel welcome. Graciously accept offers of food, drink, or assistance.
#
# 3. **Dress Modestly for Churches and Monasteries:**
#    - If you plan to visit religious sites, ensure your shoulders and knees are covered. Bring a scarf or shawl if needed.
#
# ---
#
# ### **Dining Etiquette**
# 1. **Tipping:**
#    - Tipping isn’t mandatory but is appreciated. Leaving around 5%-10% of the bill or rounding up is common.
#
# 2. **Leisurely Meals:**
#    - Meals in Greece are meant to be enjoyed slowly, often lasting hours. Don’t rush!
#
# 3. **Sharing Food:**
#    - Meals are communal, so it’s common to share dishes. Don’t hesitate to try a little of everything.
#
# ---
#
# ### **Beach and Public Areas**
# 1. **Beachwear is for the Beach:**
#    - While swimsuits are fine for beaches, it’s polite to cover up when heading to restaurants, markets, or public spaces nearby.
#
# 2. **Environmental Awareness:**
#    - Greeks take pride in their natural beauty, so avoid littering and follow local recycling rules.
#
# ---
#
# ### **Behavioral Norms**
# 1. **Punctuality:**
#    - Greeks are generally relaxed about time, especially in social situations. Don’t stress if things run behind schedule.
#
# 2. **No Flushing Toilet Paper:**
#    - In many places, especially islands, plumbing is old and fragile. Use the bins provided for toilet paper.
#
# 3. **Expressive Communication:**
#    - Greeks speak with passion and gestures. Don’t mistake it for rudeness—it’s just their way of communicating!
#
# ---
#
# ### **Local Markets and Bartering**
# 1. **Bartering:**
#    - Negotiating prices is acceptable in open markets or with vendors, but do so politely and with a smile.
#
# 2. **Taste Testing:**
#    - Vendors may offer free samples of olives, cheeses, or spices. It’s polite to try them and consider purchasing if you like it.
#
# ---
#
# ### **Unique Greek Superstitions**
# 1. **Don’t Gesture With an Open Palm:**
#    - Showing your palm outward (like a “stop” motion) can be considered offensive.
#
# 2. **Evil Eye (Mati):**
#    - Many locals wear “evil eye” charms to ward off bad luck. You may even spot these charms in markets to buy as souvenirs.
#
# ---
#
# Familiarizing yourself with these norms will ensure you have a smooth and respectful visit. Let me know if you’d like tips specific to certain islands or activities!</div>
#     </div>
# 📝 Thread has 13 messages
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #4fc3f7;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #4fc3f7; font-size: 14px;'>User:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>What's the best way to get around?</div>
#     </div>
#     <div style='
#         margin: 10px 0;
#         padding: 12px 15px;
#         border-left: 4px solid #81c784;
#         background: rgba(128, 128, 128, 0.1);
#         border-radius: 4px;
#         color: inherit;
#     '>
#         <strong style='color: #81c784; font-size: 14px;'>VacationPlannerAgent:</strong><br>
#         <div style='margin-top: 8px; white-space: pre-wrap; color: inherit; font-size: 14px;'>Getting around the Greek islands efficiently and comfortably depends on your itinerary and the specific islands you're visiting. Here's a breakdown of the best transportation options for Santorini and Mykonos, the two islands in your itinerary:
#
# ---
#
# ### **Santorini**
# 1. **Public Buses:**
#    - Affordable and reliable.
#    - Routes connect major towns like Fira, Oia, Kamari, and Perissa.
#    - Cost: Around €1.80–€2.50 per ride.
#    - Downsides: Can be crowded, especially in peak season, and schedules may not align with your plans.
#
# 2. **Rental Vehicles (Car/Scooter/ATV):**
#    - **Car:** Best for families or longer drives to remote beaches and villages.
#    - **Scooter or ATV:** Great for solo travelers or couples seeking a fun, flexible way to explore.
#    - Ensure you have an International Driving Permit (IDP) if you're visiting from outside the EU.
#
# 3. **Taxis:**
#    - Taxis are limited and can be pricey, especially for popular routes. Pre-booking is recommended through apps like Welcome Pickups or Beat.
#
# 4. **Private Transfers:**
#    - Many hotels/concierges offer private transfer options. While pricier, they're hassle-free for getting to/from ports and airports.
#
# 5. **Walking:**
#    - For short distances, walking is a scenic option, especially in towns like Oia and Fira or along the famous caldera hiking path.
#
# ---
#
# ### **Mykonos**
# 1. **Public Buses:**
#    - Efficient and budget-friendly.
#    - Serve main beaches like Paradise, Psarou, and Elia as well as Mykonos Town (Chora).
#    - Cost: Around €1.80–€3 per ticket.
#
# 2. **Rental Vehicles (Car/Scooter/ATV):**
#    - Similar to Santorini, renting a scooter or ATV is ideal for exploring beaches and less accessible areas.
#    - Roads can be narrow and busy, so drive cautiously, especially when using ATVs.
#
# 3. **Water Taxis:**
#    - Convenient for hopping between popular beaches like Super Paradise and Paraga.
#    - Fun and scenic way to travel along the coastline.
#
# 4. **Taxis:**
#    - Very limited on Mykonos (around 30 taxis total). Use taxi apps or arrange private transfers for guaranteed rides.
#
# 5. **Walking:**
#    - Perfect for exploring Mykonos Town and Little Venice, where cars are restricted. Strolling the narrow, whitewashed streets is part of the charm.
#
# ---
#
# ### **Between the Islands**
# 1. **Ferries:**
#    - The most common way to travel between Greek islands. High-speed ferries (e.g., by SeaJets or Blue Star Ferries) take around 2.5–3 hours from Santorini to Mykonos.
#    - Cost: €30–€80 per person, depending on the class and ferry type.
#    - Pro Tip: Book tickets in advance, especially during peak season.
#
# 2. **Flights:**
#    - No direct flights between Santorini and Mykonos, so you'd need to connect via Athens. Ferries are faster and more scenic.
#
# ---
#
# ### **Pro Tips:**
# - Always pre-book tickets for ferries, taxis, and rentals during peak season to avoid last-minute stress.
# - Double-check driving laws and insurance if renting a vehicle—helmet use is mandatory for scooters/ATVs.
# - Pack light for inter-island travel, as ferry and bus storage space can be limited.
#
# Let me know if you'd like assistance booking ferries, transfers, or rentals!</div>
#     </div>
# 📝 Thread has 15 messages
#
# --- Token Usage Analysis ---
# <div style='font-family: monospace; background: #2d2d2d; color: #f0f0f0; padding: 15px; border-radius: 8px; border: 1px solid #444;'><h4 style='color: #4fc3f7; margin-top: 0;'>📊 Token Usage Analysis</h4><pre style='color: #f0f0f0; margin: 0;'><span style='color: #81c784;'>Prompt Tokens per Message (shows conversation context size):</span>
# <span style='color: #aaa;'>Msg  1:</span> <span style='color: #4fc3f7;'>████████</span> <span style='color: #ffd93d;'>468 tokens</span>
# <span style='color: #aaa;'>Msg  2:</span> <span style='color: #4fc3f7;'>████████████</span> <span style='color: #ffd93d;'>745 tokens</span>
# <span style='color: #aaa;'>Msg  3:</span> <span style='color: #4fc3f7;'>███████████████</span> <span style='color: #ffd93d;'>871 tokens</span>
# <span style='color: #aaa;'>Msg  4:</span> <span style='color: #4fc3f7;'>███████████████████████████</span> <span style='color: #ffd93d;'>1,565 tokens</span>
# <span style='color: #aaa;'>Msg  5:</span> <span style='color: #4fc3f7;'>██████████████████████████████████████</span> <span style='color: #ffd93d;'>2,230 tokens</span>
# <span style='color: #aaa;'>Msg  6:</span> <span style='color: #4fc3f7;'>█████████████████████████████</span> <span style='color: #ffd93d;'>1,686 tokens</span> <span style='color: #ff6b6b;'>← REDUCTION!</span>
# <span style='color: #aaa;'>Msg  7:</span> <span style='color: #4fc3f7;'>██████████████████████████████████████</span> <span style='color: #ffd93d;'>2,192 tokens</span>
# <span style='color: #aaa;'>Msg  8:</span> <span style='color: #4fc3f7;'>██████████████████████████████████████████████████</span> <span style='color: #ffd93d;'>2,871 tokens</span>
#
# </pre></div>
# 🔄 Actual Reduction Impact:
# Prompt tokens before reduction: 2,230
# Prompt tokens after reduction: 1,686
# Tokens saved: 544 (24.4%)
#
# --- Final Scratchpad Contents ---
# 📊 Total scratchpad operations: 0
